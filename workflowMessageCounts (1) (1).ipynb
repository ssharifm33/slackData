# %% [markdown]
# # Make Slack Less Noisy 🔇
#
# This notebook allows us to categorize and sum counts of automated workflow messages.  The goal is to identify and reduce frequent notifications leading to less noise and less notification blindness

# %%
import pandas as pd
import ast
import re
from datetime import datetime
from pathlib import Path
import json

# %%
START_DATE="2024-12-01"
NOW_DATE=datetime.now().strftime('%Y-%m-%d')

# %%
# Retrieved from slack admin console
# https://lightkeeperdev.slack.com/services/export

#directory = Path('./export/update_errors/')
directory = Path('C:/Users/SamMiller/Downloads/update_errors')
pattern = re.compile(r'\d{4}-\d{2}-\d{2}')
messages = []
files = [file for file in directory.glob('*.json') if pattern.search(file.stem)]
for file in files:
    with open(file, 'r') as f:
        data = json.load(f)
        if isinstance(data, list):
            messages.extend(data)

len(messages)
# Out:
# 2763

# %% [markdown]
# ### Clean the data

# %%
def clean_message(message):
    clean = {}
    if not message.get('attachments'):
        return
    customer_search = re.search('http://(.*)\.lightkeeperhq.com\|.*',  message['attachments'][0]['title'])
    customer = customer_search.group(1)
    head = message['text']
    body = message['attachments'][0]['text']
    dt = datetime.fromtimestamp(int(float(message['ts'])))
    isAtChannel = '<!channel>' in head
    
    return {
     'customer': customer,
     'head': head,
     'body': body,
     'datetime': dt,
     'isAtChannel': isAtChannel
    }
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\.'
# <>:5: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\SamMiller\AppData\Local\Temp\ipykernel_43220\1629103741.py:5: SyntaxWarning: invalid escape sequence '\.'
#   customer_search = re.search('http://(.*)\.lightkeeperhq.com\|.*',  message['attachments'][0]['title'])

# %%
clean_messages = [clean_message(message) for message in messages]
clean_messages = [message for message in clean_messages if message]

# %%
clean_messages[1]
# Out:
# {'customer': 'lonepine',
#  'head': 'T0 ArchiveTask has not completed for 2024-12-31',
#  'body': '```An update will be sent once it has completed.```',
#  'datetime': datetime.datetime(2025, 1, 1, 0, 0, 31),
#  'isAtChannel': False}

# %%
len(clean_messages)
# Out:
# 2756

# %%
df = pd.DataFrame(clean_messages)

# %%
df.dtypes
# Out:
# customer               object
# head                   object
# body                   object
# datetime       datetime64[ns]
# isAtChannel              bool
# dtype: object

# %% [markdown]
# ### Filter and enhance

# %%
# Filter by datetime
df = df.loc[(df['datetime'] > START_DATE) & (df['datetime'] < NOW_DATE)]

# %%
# Create a map of message types we can aggregate by
MESSAGE_TYPES = {
    'daily_update_sla_fail': '^<!channel>.*Daily.*has not completed.*',
    't0_update_sla_fail': '^<!channel>.*T0.*has not completed.*',
    'broker_update_sla_fail': '.*Broker UpdateTask has not completed.*',
    'daily_missing_files': '^Daily files missing for.*',
    'daily_received_files': '^All Daily required files have now been receive.*',
    't0_missing_files': '^T0 files missing for.*',
    't0_received_files': '^All T0 required files have now been received.*',
    'build_error': '.*\.build error.*',
    'daily_non_current': '.*Daily UpdateTask.build-confirm non-current.*',
    't0_non_current': '.*T0 UpdateTask.build-confirm non-current.*',
    'daily_update_sla_recovery': 'Daily.*has now completed.*',
    't0_update_sla_recovery': 'T0.*has now completed.*',
}

df['message_type'] = df['head'].apply(lambda x: ','.join([k for k, v in MESSAGE_TYPES.items() if re.match(v, x)]) or None)
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\.'
# <>:10: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\SamMiller\AppData\Local\Temp\ipykernel_43220\3151063467.py:10: SyntaxWarning: invalid escape sequence '\.'
#   'build_error': '.*\.build error.*',

# %%
df = df.dropna()

# %%
counts = df.groupby(['message_type','customer'])['head'].count()\
                    .reset_index().sort_values(['head'], ascending=False)
countsAtChannel = df.loc[df['isAtChannel']==True].groupby(['message_type','customer'])['head'].count()\
                    .reset_index().sort_values(['head'], ascending=False)

# %% [markdown]
# ### @channel counts

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    display(countsAtChannel)
# Out:
#                message_type              customer  head
# 169      t0_update_sla_fail             tremblant    31
# 158      t0_update_sla_fail             hudsonbay    27
# 4               build_error             altimeter    16
# 30              build_error          cypressfunds    13
# 100   daily_update_sla_fail          cypressfunds    13
# 156      t0_update_sla_fail               contour     9
# 27              build_error                corvex     9
# 89    daily_update_sla_fail             altimeter     8
# 147      t0_update_sla_fail             altimeter     8
# 3               build_error              altapark     8
# 88    daily_update_sla_fail              altapark     7
# 102   daily_update_sla_fail              fortress     7
# 166      t0_update_sla_fail             slatepath     6
# 79              build_error                zimmer     5
# 99    daily_update_sla_fail             crestline     5
# 68              build_error           sunleyhouse     5
# 73              build_error             tremblant     5
# 162      t0_update_sla_fail                 junto     5
# 124   daily_update_sla_fail           sunleyhouse     5
# 138          t0_non_current           maverickcap     5
# 20              build_error        beta-tremblant     5
# 24              build_error            castlehook     4
# 25              build_error               contour     4
# 13              build_error          beta-contour     4
# 57              build_error           maverickcap     4
# 123   daily_update_sla_fail                summit     4
# 72              build_error                  toms     3
# 95    daily_update_sla_fail        beta-tremblant     3
# 67              build_error                summit     3
# 51              build_error              lingotto     3
# 54              build_error              lonepine     3
# 60              build_error                 minot     3
# 55              build_error              longpond     3
# 45              build_error              interval     3
# 65              build_error                samlyn     3
# 69              build_error              sunriver     3
# 101   daily_update_sla_fail                 eagle     3
# 70              build_error              surgocap     3
# 144      t0_update_sla_fail                 adage     3
# 168      t0_update_sla_fail                  toms     3
# 41              build_error                 helix     3
# 8               build_error                 arosa     3
# 133   daily_update_sla_fail                zimmer     3
# 117   daily_update_sla_fail                 minot     3
# 122   daily_update_sla_fail               soroban     3
# 128   daily_update_sla_fail             tremblant     3
# 0    broker_update_sla_fail                dorsal     2
# 26              build_error            conversant     2
# 10              build_error              bayberry     2
# 112   daily_update_sla_fail               lombard     2
# 80        daily_non_current        beta-tremblant     2
# 92    daily_update_sla_fail  beta-1-ideaanalytics     2
# 87        daily_non_current                zimmer     2
# 151      t0_update_sla_fail          avalonglobal     2
# 157      t0_update_sla_fail                 engle     2
# 172      t0_update_sla_fail                zimmer     2
# 148      t0_update_sla_fail               anomaly     2
# 153      t0_update_sla_fail          beta-contour     2
# 134          t0_non_current           ardmoreroad     2
# 111   daily_update_sla_fail              lingotto     2
# 131   daily_update_sla_fail     washingtonharbour     2
# 74              build_error              valueact     2
# 63              build_error                  rdst     2
# 56              build_error               maltese     2
# 83        daily_non_current               lombard     2
# 78              build_error                 weiss     2
# 59              build_error            millstreet     2
# 49              build_error                   jne     2
# 47              build_error                   ion     2
# 43              build_error              honeypot     2
# 33              build_error                 engle     2
# 14              build_error       beta-conversant     2
# 15              build_error               beta-d1     2
# 32              build_error                dorsal     2
# 31              build_error                    d1     2
# 1    broker_update_sla_fail              longpond     1
# 2    broker_update_sla_fail                summit     1
# 44              build_error       ias-maverickcap     1
# 42              build_error             honeycomb     1
# 39              build_error              gppfunds     1
# 40              build_error                  gsam     1
# 38              build_error            goldentree     1
# 37              build_error              fortress     1
# 35              build_error           ezesoftware     1
# 36              build_error             fairmount     1
# 34              build_error                ezedev     1
# 29              build_error             crosslink     1
# 17              build_error            beta-invus     1
# 16              build_error           beta-dorsal     1
# 23              build_error                camber     1
# 22              build_error             braidwell     1
# 21              build_error      beta-waterstreet     1
# 28              build_error             crestline     1
# 18              build_error         beta-lingotto     1
# 19              build_error         beta-strategy     1
# 6               build_error           ardmoreroad     1
# 5               build_error               aluacap     1
# 7               build_error              aregence     1
# 9               build_error                 atika     1
# 11              build_error       beta-1-aventail     1
# 12              build_error            beta-1-see     1
# 76              build_error           vestalpoint     1
# 75              build_error              veristar     1
# 71              build_error             thorntree     1
# 66              build_error                   srs     1
# 64              build_error           rocksprings     1
# 62              build_error                 munro     1
# 61              build_error              monashee     1
# 58              build_error                   mig     1
# 108   daily_update_sla_fail              ideamgmt     1
# 107   daily_update_sla_fail       ias-maverickcap     1
# 106   daily_update_sla_fail                 helix     1
# 105   daily_update_sla_fail                  gsam     1
# 104   daily_update_sla_fail              gppfunds     1
# 103   daily_update_sla_fail            goldentree     1
# 98    daily_update_sla_fail                corvex     1
# 97    daily_update_sla_fail            castlehook     1
# 93    daily_update_sla_fail          beta-contour     1
# 96    daily_update_sla_fail                camber     1
# 94    daily_update_sla_fail               beta-d1     1
# 77              build_error     washingtonharbour     1
# 85        daily_non_current                  rdst     1
# 86        daily_non_current             twocreeks     1
# 90    daily_update_sla_fail              bayberry     1
# 91    daily_update_sla_fail       beta-1-aventail     1
# 82        daily_non_current             honeycomb     1
# 81        daily_non_current              cartenna     1
# 84        daily_non_current              monashee     1
# 53              build_error               lombard     1
# 48              build_error          irontriangle     1
# 46              build_error         intrinsicedge     1
# 50              build_error            kettlehill     1
# 52              build_error               linonia     1
# 121   daily_update_sla_fail                   see     1
# 118   daily_update_sla_fail                paloma     1
# 119   daily_update_sla_fail                  rdst     1
# 114   daily_update_sla_fail               maltese     1
# 116   daily_update_sla_fail                   mig     1
# 115   daily_update_sla_fail           maverickcap     1
# 110   daily_update_sla_fail                 junto     1
# 109   daily_update_sla_fail                   jne     1
# 140          t0_non_current                  rdst     1
# 139          t0_non_current              monashee     1
# 137          t0_non_current                 helix     1
# 136          t0_non_current                camber     1
# 135          t0_non_current                 atika     1
# 129   daily_update_sla_fail             twocreeks     1
# 130   daily_update_sla_fail              veristar     1
# 132   daily_update_sla_fail                 weiss     1
# 125   daily_update_sla_fail              sunriver     1
# 126   daily_update_sla_fail              surgocap     1
# 127   daily_update_sla_fail                  toms     1
# 113   daily_update_sla_fail              longpond     1
# 120   daily_update_sla_fail                samlyn     1
# 145      t0_update_sla_fail               adelphi     1
# 143          t0_non_current               waratah     1
# 141          t0_non_current            sourcerock     1
# 155      t0_update_sla_fail             braidwell     1
# 154      t0_update_sla_fail        beta-tremblant     1
# 150      t0_update_sla_fail                 arosa     1
# 152      t0_update_sla_fail       beta-1-aventail     1
# 149      t0_update_sla_fail              aregence     1
# 142          t0_non_current                  toms     1
# 146      t0_update_sla_fail              altapark     1
# 159      t0_update_sla_fail              interval     1
# 164      t0_update_sla_fail           maverickcap     1
# 163      t0_update_sla_fail              longpond     1
# 161      t0_update_sla_fail                   jne     1
# 160      t0_update_sla_fail         intrinsicedge     1
# 167      t0_update_sla_fail              surgocap     1
# 165      t0_update_sla_fail                  rdst     1
# 170      t0_update_sla_fail              twosigma     1
# 171      t0_update_sla_fail               waratah     1

# %% [markdown]
# ### Non-alerting workflow counts

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    display(counts)
# Out:
#                   message_type              customer  head
# 278           t0_missing_files             tremblant    71
# 321          t0_received_files             tremblant    69
# 318          t0_received_files             slatepath    68
# 275           t0_missing_files             slatepath    65
# 373     t0_update_sla_recovery             tremblant    53
# 365     t0_update_sla_recovery             hudsonbay    52
# 323          t0_received_files               vivaldi    48
# 308          t0_received_files             hudsonbay    45
# 313          t0_received_files              lonepine    35
# 305          t0_received_files                 engle    33
# 156       daily_received_files              lonepine    31
# 350         t0_update_sla_fail             tremblant    31
# 339         t0_update_sla_fail             hudsonbay    27
# 255           t0_missing_files        beta-tremblant    27
# 264           t0_missing_files                 helix    26
# 306          t0_received_files                 helix    26
# 295          t0_received_files          avalonglobal    25
# 106        daily_missing_files              lonepine    24
# 153       daily_received_files                 helix    21
# 300          t0_received_files        beta-tremblant    19
# 98         daily_missing_files              fortress    19
# 368     t0_update_sla_recovery                 junto    17
# 219  daily_update_sla_recovery             crestline    17
# 97         daily_missing_files             fairmount    17
# 280           t0_missing_files                zimmer    17
# 266           t0_missing_files             hudsonbay    16
# 146       daily_received_files             fairmount    16
# 250           t0_missing_files          avalonglobal    16
# 4                  build_error             altimeter    16
# 324          t0_received_files                zimmer    15
# 247           t0_missing_files                   ako    15
# 293          t0_received_files                   ako    15
# 90         daily_missing_files             braidwell    14
# 141       daily_received_files             braidwell    14
# 144       daily_received_files            conversant    14
# 181      daily_update_sla_fail          cypressfunds    13
# 30                 build_error          cypressfunds    13
# 256           t0_missing_files         beta-valueact    12
# 140       daily_received_files         beta-valueact    12
# 292          t0_received_files               adelphi    12
# 246           t0_missing_files               adelphi    12
# 303          t0_received_files               contour    11
# 260           t0_missing_files               contour    11
# 237  daily_update_sla_recovery               soroban    11
# 267           t0_missing_files                   ion    11
# 88         daily_missing_files        beta-tremblant     9
# 337         t0_update_sla_fail               contour     9
# 309          t0_received_files                   ion     9
# 27                 build_error                corvex     9
# 87         daily_missing_files       beta-sachemhead     9
# 103        daily_missing_files              jennison     9
# 166       daily_received_files              valueact     9
# 298          t0_received_files            beta-junto     8
# 170      daily_update_sla_fail             altimeter     8
# 254           t0_missing_files            beta-junto     8
# 307          t0_received_files             honeycomb     8
# 328         t0_update_sla_fail             altimeter     8
# 371     t0_update_sla_recovery             slatepath     8
# 265           t0_missing_files             honeycomb     8
# 138       daily_received_files            beta-junto     8
# 86         daily_missing_files            beta-junto     8
# 3                  build_error              altapark     8
# 108        daily_missing_files              magnetar     7
# 183      daily_update_sla_fail              fortress     7
# 268           t0_missing_files               jericho     7
# 169      daily_update_sla_fail              altapark     7
# 310          t0_received_files               jericho     7
# 154       daily_received_files              jennison     6
# 369     t0_update_sla_recovery              lonepine     6
# 152       daily_received_files                  gsam     6
# 299          t0_received_files         beta-lonepine     6
# 317          t0_received_files           rocksprings     6
# 347         t0_update_sla_fail             slatepath     6
# 362     t0_update_sla_recovery               contour     6
# 102        daily_missing_files                  gsam     6
# 150       daily_received_files            goldentree     6
# 261           t0_missing_files                corvex     6
# 274           t0_missing_files           rocksprings     6
# 95         daily_missing_files             crestline     6
# 93         daily_missing_files               contour     6
# 205      daily_update_sla_fail           sunleyhouse     5
# 117        daily_missing_files                   sir     5
# 116        daily_missing_files                scopia     5
# 272           t0_missing_files                 munro     5
# 79                 build_error                zimmer     5
# 73                 build_error             tremblant     5
# 68                 build_error           sunleyhouse     5
# 319          t0_received_files              sunriver     5
# 315          t0_received_files                 munro     5
# 20                 build_error        beta-tremblant     5
# 343         t0_update_sla_fail                 junto     5
# 180      daily_update_sla_fail             crestline     5
# 245           t0_missing_files                 adage     5
# 94         daily_missing_files                corvex     5
# 285             t0_non_current           maverickcap     5
# 101        daily_missing_files            goldentree     5
# 118        daily_missing_files               soroban     5
# 276           t0_missing_files              sunriver     5
# 291          t0_received_files                 adage     5
# 204      daily_update_sla_fail                summit     4
# 361     t0_update_sla_recovery             braidwell     4
# 259           t0_missing_files            castlehook     4
# 136       daily_received_files              bayberry     4
# 139       daily_received_files        beta-tremblant     4
# 115        daily_missing_files            sachemhead     4
# 84         daily_missing_files              bayberry     4
# 311          t0_received_files                 junto     4
# 57                 build_error           maverickcap     4
# 13                 build_error          beta-contour     4
# 220  daily_update_sla_recovery          cypressfunds     4
# 302          t0_received_files            castlehook     4
# 24                 build_error            castlehook     4
# 25                 build_error               contour     4
# 82         daily_missing_files          avalonglobal     4
# 349         t0_update_sla_fail                  toms     3
# 67                 build_error                summit     3
# 325         t0_update_sla_fail                 adage     3
# 354     t0_update_sla_recovery                 adage     3
# 8                  build_error                 arosa     3
# 182      daily_update_sla_fail                 eagle     3
# 209      daily_update_sla_fail             tremblant     3
# 198      daily_update_sla_fail                 minot     3
# 279           t0_missing_files              valueact     3
# 109        daily_missing_files               maltese     3
# 273           t0_missing_files                  rdst     3
# 123        daily_missing_files     washingtonharbour     3
# 45                 build_error              interval     3
# 51                 build_error              lingotto     3
# 322          t0_received_files              valueact     3
# 41                 build_error                 helix     3
# 54                 build_error              lonepine     3
# 65                 build_error                samlyn     3
# 55                 build_error              longpond     3
# 60                 build_error                 minot     3
# 81         daily_missing_files               artisan     3
# 72                 build_error                  toms     3
# 70                 build_error              surgocap     3
# 69                 build_error              sunriver     3
# 134       daily_received_files               artisan     3
# 230  daily_update_sla_recovery               lombard     3
# 176      daily_update_sla_fail        beta-tremblant     3
# 167       daily_received_files     washingtonharbour     3
# 214      daily_update_sla_fail                zimmer     3
# 363     t0_update_sla_recovery            conversant     3
# 221  daily_update_sla_recovery                 eagle     3
# 203      daily_update_sla_fail               soroban     3
# 74                 build_error              valueact     2
# 78                 build_error                 weiss     2
# 56                 build_error               maltese     2
# 59                 build_error            millstreet     2
# 43                 build_error              honeypot     2
# 47                 build_error                   ion     2
# 49                 build_error                   jne     2
# 320          t0_received_files             thorntree     2
# 31                 build_error                    d1     2
# 0       broker_update_sla_fail                dorsal     2
# 353         t0_update_sla_fail                zimmer     2
# 372     t0_update_sla_recovery                  toms     2
# 63                 build_error                  rdst     2
# 32                 build_error                dorsal     2
# 33                 build_error                 engle     2
# 26                 build_error            conversant     2
# 329         t0_update_sla_fail               anomaly     2
# 332         t0_update_sla_fail          avalonglobal     2
# 334         t0_update_sla_fail          beta-contour     2
# 338         t0_update_sla_fail                 engle     2
# 85         daily_missing_files          beta-contour     2
# 113        daily_missing_files                  rdst     2
# 281             t0_non_current           ardmoreroad     2
# 277           t0_missing_files             thorntree     2
# 135       daily_received_files          avalonglobal     2
# 143       daily_received_files               catrock     2
# 147       daily_received_files              fortress     2
# 145       daily_received_files             crestline     2
# 263           t0_missing_files                  gsam     2
# 128          daily_non_current               lombard     2
# 125          daily_non_current        beta-tremblant     2
# 271           t0_missing_files            millstreet     2
# 120        daily_missing_files           tigerglobal     2
# 121        daily_missing_files             tremblant     2
# 96         daily_missing_files                dorsal     2
# 92         daily_missing_files               catrock     2
# 158       daily_received_files                 munro     2
# 163       daily_received_files               soroban     2
# 132          daily_non_current                zimmer     2
# 244  daily_update_sla_recovery     washingtonharbour     2
# 193      daily_update_sla_fail               lombard     2
# 229  daily_update_sla_recovery              lingotto     2
# 239  daily_update_sla_recovery           sunleyhouse     2
# 238  daily_update_sla_recovery                summit     2
# 240  daily_update_sla_recovery             tremblant     2
# 165       daily_received_files             tremblant     2
# 173      daily_update_sla_fail  beta-1-ideaanalytics     2
# 192      daily_update_sla_fail              lingotto     2
# 212      daily_update_sla_fail     washingtonharbour     2
# 364     t0_update_sla_recovery                 engle     2
# 359     t0_update_sla_recovery          avalonglobal     2
# 357     t0_update_sla_recovery               anomaly     2
# 14                 build_error       beta-conversant     2
# 15                 build_error               beta-d1     2
# 356     t0_update_sla_recovery             altimeter     2
# 10                 build_error              bayberry     2
# 5                  build_error               aluacap     1
# 6                  build_error           ardmoreroad     1
# 7                  build_error              aregence     1
# 9                  build_error                 atika     1
# 11                 build_error       beta-1-aventail     1
# 12                 build_error            beta-1-see     1
# 16                 build_error           beta-dorsal     1
# 17                 build_error            beta-invus     1
# 18                 build_error         beta-lingotto     1
# 19                 build_error         beta-strategy     1
# 358     t0_update_sla_recovery              aregence     1
# 360     t0_update_sla_recovery       beta-1-aventail     1
# 366     t0_update_sla_recovery              interval     1
# 367     t0_update_sla_recovery         intrinsicedge     1
# 370     t0_update_sla_recovery                  rdst     1
# 196      daily_update_sla_fail           maverickcap     1
# 197      daily_update_sla_fail                   mig     1
# 199      daily_update_sla_fail                paloma     1
# 200      daily_update_sla_fail                  rdst     1
# 201      daily_update_sla_fail                samlyn     1
# 202      daily_update_sla_fail                   see     1
# 206      daily_update_sla_fail              sunriver     1
# 207      daily_update_sla_fail              surgocap     1
# 208      daily_update_sla_fail                  toms     1
# 210      daily_update_sla_fail             twocreeks     1
# 211      daily_update_sla_fail              veristar     1
# 213      daily_update_sla_fail                 weiss     1
# 215  daily_update_sla_recovery             altimeter     1
# 216  daily_update_sla_recovery       beta-1-aventail     1
# 217  daily_update_sla_recovery        beta-tremblant     1
# 218  daily_update_sla_recovery                corvex     1
# 222  daily_update_sla_recovery              fortress     1
# 223  daily_update_sla_recovery            goldentree     1
# 224  daily_update_sla_recovery                  gsam     1
# 225  daily_update_sla_recovery                 helix     1
# 226  daily_update_sla_recovery       ias-maverickcap     1
# 227  daily_update_sla_recovery              ideamgmt     1
# 184      daily_update_sla_fail            goldentree     1
# 185      daily_update_sla_fail              gppfunds     1
# 186      daily_update_sla_fail                  gsam     1
# 187      daily_update_sla_fail                 helix     1
# 188      daily_update_sla_fail       ias-maverickcap     1
# 189      daily_update_sla_fail              ideamgmt     1
# 190      daily_update_sla_fail                   jne     1
# 191      daily_update_sla_fail                 junto     1
# 194      daily_update_sla_fail              longpond     1
# 195      daily_update_sla_fail               maltese     1
# 228  daily_update_sla_recovery                 junto     1
# 231  daily_update_sla_recovery               maltese     1
# 232  daily_update_sla_recovery                   mig     1
# 233  daily_update_sla_recovery                paloma     1
# 234  daily_update_sla_recovery           rocksprings     1
# 235  daily_update_sla_recovery                samlyn     1
# 236  daily_update_sla_recovery                   see     1
# 241  daily_update_sla_recovery             twocreeks     1
# 242  daily_update_sla_recovery              veristar     1
# 243  daily_update_sla_recovery           vestalpoint     1
# 164       daily_received_files              sunriver     1
# 168       daily_received_files                yiheng     1
# 171      daily_update_sla_fail              bayberry     1
# 172      daily_update_sla_fail       beta-1-aventail     1
# 174      daily_update_sla_fail          beta-contour     1
# 175      daily_update_sla_fail               beta-d1     1
# 177      daily_update_sla_fail                camber     1
# 178      daily_update_sla_fail            castlehook     1
# 179      daily_update_sla_fail                corvex     1
# 248           t0_missing_files                 arosa     1
# 249           t0_missing_files                 atika     1
# 251           t0_missing_files                 avoro     1
# 252           t0_missing_files              beta-ako     1
# 253           t0_missing_files          beta-contour     1
# 257           t0_missing_files                 boone     1
# 258           t0_missing_files               bridger     1
# 148       daily_received_files               frazier     1
# 149       daily_received_files             gamecreek     1
# 151       daily_received_files              gppfunds     1
# 155       daily_received_files                 junto     1
# 157       daily_received_files              longpond     1
# 159       daily_received_files                paloma     1
# 160       daily_received_files                  rdst     1
# 161       daily_received_files            sachemhead     1
# 162       daily_received_files                   sir     1
# 133       daily_received_files                 arosa     1
# 137       daily_received_files       beta-1-aventail     1
# 142       daily_received_files            castlehook     1
# 262           t0_missing_files               frazier     1
# 269           t0_missing_files               kinetic     1
# 270           t0_missing_files              longpond     1
# 119        daily_missing_files              sunriver     1
# 122        daily_missing_files              valueact     1
# 124        daily_missing_files                yiheng     1
# 126          daily_non_current              cartenna     1
# 127          daily_non_current             honeycomb     1
# 129          daily_non_current              monashee     1
# 130          daily_non_current                  rdst     1
# 131          daily_non_current             twocreeks     1
# 282             t0_non_current                 atika     1
# 283             t0_non_current                camber     1
# 284             t0_non_current                 helix     1
# 286             t0_non_current              monashee     1
# 287             t0_non_current                  rdst     1
# 288             t0_non_current            sourcerock     1
# 289             t0_non_current                  toms     1
# 290             t0_non_current               waratah     1
# 100        daily_missing_files             gamecreek     1
# 104        daily_missing_files                 junto     1
# 105        daily_missing_files             kathmandu     1
# 107        daily_missing_files              longpond     1
# 110        daily_missing_files            millstreet     1
# 111        daily_missing_files                 munro     1
# 112        daily_missing_files                paloma     1
# 114        daily_missing_files           rocksprings     1
# 89         daily_missing_files                 boone     1
# 91         daily_missing_files            castlehook     1
# 99         daily_missing_files               frazier     1
# 294          t0_received_files                 atika     1
# 296          t0_received_files                 avoro     1
# 297          t0_received_files              beta-ako     1
# 301          t0_received_files               bridger     1
# 304          t0_received_files                corvex     1
# 71                 build_error             thorntree     1
# 75                 build_error              veristar     1
# 76                 build_error           vestalpoint     1
# 77                 build_error     washingtonharbour     1
# 80         daily_missing_files                 arosa     1
# 83         daily_missing_files              aventail     1
# 52                 build_error               linonia     1
# 53                 build_error               lombard     1
# 58                 build_error                   mig     1
# 61                 build_error              monashee     1
# 62                 build_error                 munro     1
# 64                 build_error           rocksprings     1
# 66                 build_error                   srs     1
# 312          t0_received_files               kinetic     1
# 314          t0_received_files              longpond     1
# 316          t0_received_files                  rdst     1
# 36                 build_error             fairmount     1
# 37                 build_error              fortress     1
# 38                 build_error            goldentree     1
# 39                 build_error              gppfunds     1
# 40                 build_error                  gsam     1
# 42                 build_error             honeycomb     1
# 44                 build_error       ias-maverickcap     1
# 46                 build_error         intrinsicedge     1
# 48                 build_error          irontriangle     1
# 50                 build_error            kettlehill     1
# 326         t0_update_sla_fail               adelphi     1
# 327         t0_update_sla_fail              altapark     1
# 330         t0_update_sla_fail              aregence     1
# 331         t0_update_sla_fail                 arosa     1
# 333         t0_update_sla_fail       beta-1-aventail     1
# 335         t0_update_sla_fail        beta-tremblant     1
# 336         t0_update_sla_fail             braidwell     1
# 21                 build_error      beta-waterstreet     1
# 22                 build_error             braidwell     1
# 23                 build_error                camber     1
# 28                 build_error             crestline     1
# 29                 build_error             crosslink     1
# 34                 build_error                ezedev     1
# 35                 build_error           ezesoftware     1
# 340         t0_update_sla_fail              interval     1
# 341         t0_update_sla_fail         intrinsicedge     1
# 342         t0_update_sla_fail                   jne     1
# 344         t0_update_sla_fail              longpond     1
# 345         t0_update_sla_fail           maverickcap     1
# 346         t0_update_sla_fail                  rdst     1
# 348         t0_update_sla_fail              surgocap     1
# 351         t0_update_sla_fail              twosigma     1
# 352         t0_update_sla_fail               waratah     1
# 355     t0_update_sla_recovery               adelphi     1
# 2       broker_update_sla_fail                summit     1
# 1       broker_update_sla_fail              longpond     1
# 374     t0_update_sla_recovery               waratah     1
# 375     t0_update_sla_recovery                zimmer     1

# %% [markdown]
# ### Latest Daily Recovery Times

# %%
dailyRecoveryMessages = df[df['message_type'] == 'daily_update_sla_recovery'] 
latestTimes = dailyRecoveryMessages.groupby(['customer', 'message_type'])['datetime'].max().reset_index()
display(latestTimes)
# Out:
#              customer               message_type            datetime
# 0           altimeter  daily_update_sla_recovery 2025-04-04 09:44:57
# 1     beta-1-aventail  daily_update_sla_recovery 2025-01-07 11:46:48
# 2      beta-tremblant  daily_update_sla_recovery 2025-01-02 09:10:34
# 3              corvex  daily_update_sla_recovery 2025-02-12 11:22:49
# 4           crestline  daily_update_sla_recovery 2025-04-09 12:47:56
# 5        cypressfunds  daily_update_sla_recovery 2025-03-03 09:52:56
# 6               eagle  daily_update_sla_recovery 2025-03-11 09:02:48
# 7            fortress  daily_update_sla_recovery 2025-03-06 13:11:49
# 8          goldentree  daily_update_sla_recovery 2025-02-03 08:49:30
# 9                gsam  daily_update_sla_recovery 2025-01-01 10:14:01
# 10              helix  daily_update_sla_recovery 2025-01-26 09:45:40
# 11    ias-maverickcap  daily_update_sla_recovery 2025-01-17 09:02:03
# 12           ideamgmt  daily_update_sla_recovery 2025-03-04 15:15:32
# 13              junto  daily_update_sla_recovery 2025-03-08 08:42:30
# 14           lingotto  daily_update_sla_recovery 2025-04-01 19:06:03
# 15            lombard  daily_update_sla_recovery 2025-04-07 07:12:40
# 16            maltese  daily_update_sla_recovery 2025-01-23 10:54:42
# 17                mig  daily_update_sla_recovery 2025-02-19 08:50:52
# 18             paloma  daily_update_sla_recovery 2025-02-05 11:35:17
# 19        rocksprings  daily_update_sla_recovery 2025-01-29 08:02:31
# 20             samlyn  daily_update_sla_recovery 2025-02-03 09:00:57
# 21                see  daily_update_sla_recovery 2025-03-27 13:30:39
# 22            soroban  daily_update_sla_recovery 2025-03-29 15:18:03
# 23             summit  daily_update_sla_recovery 2025-02-13 10:20:44
# 24        sunleyhouse  daily_update_sla_recovery 2025-01-23 12:09:21
# 25          tremblant  daily_update_sla_recovery 2025-02-12 11:47:51
# 26          twocreeks  daily_update_sla_recovery 2025-03-05 09:56:48
# 27           veristar  daily_update_sla_recovery 2025-03-04 12:31:53
# 28        vestalpoint  daily_update_sla_recovery 2025-03-21 09:40:18
# 29  washingtonharbour  daily_update_sla_recovery 2025-04-02 12:03:48

# %% [markdown]
# ### Latest T0 Recovery Times

# %%
dailyRecoveryMessages = df[df['message_type'] == 't0_update_sla_recovery'] 
latestTimes = dailyRecoveryMessages.groupby(['customer', 'message_type'])['datetime'].max().reset_index()
display(latestTimes)
# Out:
#            customer            message_type            datetime
# 0             adage  t0_update_sla_recovery 2025-01-06 23:38:09
# 1           adelphi  t0_update_sla_recovery 2025-04-01 20:00:25
# 2         altimeter  t0_update_sla_recovery 2025-04-04 10:04:20
# 3           anomaly  t0_update_sla_recovery 2025-02-14 19:06:51
# 4          aregence  t0_update_sla_recovery 2025-01-27 21:04:29
# 5      avalonglobal  t0_update_sla_recovery 2025-03-24 00:00:33
# 6   beta-1-aventail  t0_update_sla_recovery 2025-01-02 20:25:31
# 7         braidwell  t0_update_sla_recovery 2025-04-07 18:32:41
# 8           contour  t0_update_sla_recovery 2025-03-14 21:04:07
# 9        conversant  t0_update_sla_recovery 2025-01-13 17:30:31
# 10            engle  t0_update_sla_recovery 2025-03-12 21:25:43
# 11        hudsonbay  t0_update_sla_recovery 2025-04-10 01:01:48
# 12         interval  t0_update_sla_recovery 2025-01-22 19:06:20
# 13    intrinsicedge  t0_update_sla_recovery 2025-01-15 19:46:47
# 14            junto  t0_update_sla_recovery 2025-04-09 19:46:29
# 15         lonepine  t0_update_sla_recovery 2025-01-14 00:10:19
# 16             rdst  t0_update_sla_recovery 2025-03-05 20:00:36
# 17        slatepath  t0_update_sla_recovery 2025-04-08 19:27:28
# 18             toms  t0_update_sla_recovery 2025-03-03 20:16:56
# 19        tremblant  t0_update_sla_recovery 2025-04-07 21:47:30
# 20          waratah  t0_update_sla_recovery 2025-01-03 01:04:40
# 21           zimmer  t0_update_sla_recovery 2025-01-21 19:30:11
