# %% [markdown]
# # Make Slack Less Noisy 🔇
#
# This notebook allows us to categorize and sum counts of automated workflow messages.  The goal is to identify and reduce frequent notifications leading to less noise and less notification blindness

# %%
import pandas as pd
import ast
import re
from datetime import datetime
from pathlib import Path
import json

# %%
START_DATE="2024-12-01"
NOW_DATE=datetime.now().strftime('%Y-%m-%d')

# %%
# Retrieved from slack admin console
# https://lightkeeperdev.slack.com/services/export

#directory = Path('./export/update_errors/')
directory = Path('C:/Users/SamMiller/Downloads/update_errors')
pattern = re.compile(r'\d{4}-\d{2}-\d{2}')
messages = []
files = [file for file in directory.glob('*.json') if pattern.search(file.stem)]
for file in files:
    with open(file, 'r') as f:
        data = json.load(f)
        if isinstance(data, list):
            messages.extend(data)

len(messages)
# Out:
# 2763

# %% [markdown]
# ### Clean the data

# %%
# Fix the regex pattern in the clean_message function
def clean_message(message):
    clean = {}
    if not message.get('attachments'):
        return
    # Use raw string r'pattern' or double escape backslashes
    customer_search = re.search(r'http://(.*?)\.lightkeeperhq\.com\|.*', message['attachments'][0]['title'])
    if not customer_search:
        return
    customer = customer_search.group(1)
    head = message['text']
    body = message['attachments'][0]['text']
    dt = datetime.fromtimestamp(int(float(message['ts'])))
    isAtChannel = '<!channel>' in head
    
    return {
     'customer': customer,
     'head': head,
     'body': body,
     'datetime': dt,
     'isAtChannel': isAtChannel
    }

# %%
clean_messages = [clean_message(message) for message in messages]
clean_messages = [message for message in clean_messages if message]

# %%
clean_messages[1]
# Out:
# {'customer': 'lonepine',
#  'head': 'T0 ArchiveTask has not completed for 2024-12-31',
#  'body': '```An update will be sent once it has completed.```',
#  'datetime': datetime.datetime(2025, 1, 1, 0, 0, 31),
#  'isAtChannel': False}

# %%
len(clean_messages)
# Out:
# 2756

# %%
df = pd.DataFrame(clean_messages)

# %%
df.dtypes
# Out:
# customer               object
# head                   object
# body                   object
# datetime       datetime64[ns]
# isAtChannel              bool
# dtype: object

# %% [markdown]
# ### Filter and enhance

# %%
# Filter by datetime
df = df.loc[(df['datetime'] > START_DATE) & (df['datetime'] < NOW_DATE)]

# %%
# Create a map of message types we can aggregate by
MESSAGE_TYPES = {
    'daily_update_sla_fail': '^<!channel>.*Daily.*has not completed.*',
    't0_update_sla_fail': '^<!channel>.*T0.*has not completed.*',
    'broker_update_sla_fail': '.*Broker UpdateTask has not completed.*',
    'daily_missing_files': '^Daily files missing for.*',
    'daily_received_files': '^All Daily required files have now been receive.*',
    't0_missing_files': '^T0 files missing for.*',
    't0_received_files': '^All T0 required files have now been received.*',
    'build_error': '.*/.build error.*',
    'daily_non_current': '.*Daily UpdateTask.build-confirm non-current.*',
    't0_non_current': '.*T0 UpdateTask.build-confirm non-current.*',
    'daily_update_sla_recovery': 'Daily.*has now completed.*',
    't0_update_sla_recovery': 'T0.*has now completed.*',
}

df['message_type'] = df['head'].apply(lambda x: ','.join([k for k, v in MESSAGE_TYPES.items() if re.match(v, x)]) or None)

# %%
df = df.dropna()

# %%
counts = df.groupby(['message_type','customer'])['head'].count()\
                    .reset_index().sort_values(['head'], ascending=False)
countsAtChannel = df.loc[df['isAtChannel']==True].groupby(['message_type','customer'])['head'].count()\
                    .reset_index().sort_values(['head'], ascending=False)

# %% [markdown]
# ### @channel counts

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    display(countsAtChannel)
# Out:
#               message_type              customer  head
# 92      t0_update_sla_fail             tremblant    31
# 81      t0_update_sla_fail             hudsonbay    27
# 23   daily_update_sla_fail          cypressfunds    13
# 79      t0_update_sla_fail               contour     9
# 70      t0_update_sla_fail             altimeter     8
# 12   daily_update_sla_fail             altimeter     8
# 25   daily_update_sla_fail              fortress     7
# 11   daily_update_sla_fail              altapark     7
# 89      t0_update_sla_fail             slatepath     6
# 61          t0_non_current           maverickcap     5
# 47   daily_update_sla_fail           sunleyhouse     5
# 85      t0_update_sla_fail                 junto     5
# 22   daily_update_sla_fail             crestline     5
# 46   daily_update_sla_fail                summit     4
# 24   daily_update_sla_fail                 eagle     3
# 18   daily_update_sla_fail        beta-tremblant     3
# 45   daily_update_sla_fail               soroban     3
# 40   daily_update_sla_fail                 minot     3
# 56   daily_update_sla_fail                zimmer     3
# 51   daily_update_sla_fail             tremblant     3
# 67      t0_update_sla_fail                 adage     3
# 91      t0_update_sla_fail                  toms     3
# 35   daily_update_sla_fail               lombard     2
# 0   broker_update_sla_fail                dorsal     2
# 10       daily_non_current                zimmer     2
# 15   daily_update_sla_fail  beta-1-ideaanalytics     2
# 6        daily_non_current               lombard     2
# 3        daily_non_current        beta-tremblant     2
# 76      t0_update_sla_fail          beta-contour     2
# 57          t0_non_current           ardmoreroad     2
# 34   daily_update_sla_fail              lingotto     2
# 54   daily_update_sla_fail     washingtonharbour     2
# 71      t0_update_sla_fail               anomaly     2
# 95      t0_update_sla_fail                zimmer     2
# 80      t0_update_sla_fail                 engle     2
# 74      t0_update_sla_fail          avalonglobal     2
# 31   daily_update_sla_fail              ideamgmt     1
# 30   daily_update_sla_fail       ias-maverickcap     1
# 29   daily_update_sla_fail                 helix     1
# 28   daily_update_sla_fail                  gsam     1
# 16   daily_update_sla_fail          beta-contour     1
# 19   daily_update_sla_fail                camber     1
# 17   daily_update_sla_fail               beta-d1     1
# 2   broker_update_sla_fail                summit     1
# 8        daily_non_current                  rdst     1
# 9        daily_non_current             twocreeks     1
# 13   daily_update_sla_fail              bayberry     1
# 14   daily_update_sla_fail       beta-1-aventail     1
# 1   broker_update_sla_fail              longpond     1
# 4        daily_non_current              cartenna     1
# 5        daily_non_current             honeycomb     1
# 7        daily_non_current              monashee     1
# 27   daily_update_sla_fail              gppfunds     1
# 26   daily_update_sla_fail            goldentree     1
# 21   daily_update_sla_fail                corvex     1
# 20   daily_update_sla_fail            castlehook     1
# 44   daily_update_sla_fail                   see     1
# 41   daily_update_sla_fail                paloma     1
# 42   daily_update_sla_fail                  rdst     1
# 37   daily_update_sla_fail               maltese     1
# 39   daily_update_sla_fail                   mig     1
# 38   daily_update_sla_fail           maverickcap     1
# 33   daily_update_sla_fail                 junto     1
# 32   daily_update_sla_fail                   jne     1
# 63          t0_non_current                  rdst     1
# 62          t0_non_current              monashee     1
# 60          t0_non_current                 helix     1
# 59          t0_non_current                camber     1
# 58          t0_non_current                 atika     1
# 52   daily_update_sla_fail             twocreeks     1
# 53   daily_update_sla_fail              veristar     1
# 55   daily_update_sla_fail                 weiss     1
# 48   daily_update_sla_fail              sunriver     1
# 49   daily_update_sla_fail              surgocap     1
# 50   daily_update_sla_fail                  toms     1
# 36   daily_update_sla_fail              longpond     1
# 43   daily_update_sla_fail                samlyn     1
# 68      t0_update_sla_fail               adelphi     1
# 66          t0_non_current               waratah     1
# 64          t0_non_current            sourcerock     1
# 78      t0_update_sla_fail             braidwell     1
# 77      t0_update_sla_fail        beta-tremblant     1
# 73      t0_update_sla_fail                 arosa     1
# 75      t0_update_sla_fail       beta-1-aventail     1
# 72      t0_update_sla_fail              aregence     1
# 65          t0_non_current                  toms     1
# 69      t0_update_sla_fail              altapark     1
# 82      t0_update_sla_fail              interval     1
# 87      t0_update_sla_fail           maverickcap     1
# 86      t0_update_sla_fail              longpond     1
# 84      t0_update_sla_fail                   jne     1
# 83      t0_update_sla_fail         intrinsicedge     1
# 90      t0_update_sla_fail              surgocap     1
# 88      t0_update_sla_fail                  rdst     1
# 93      t0_update_sla_fail              twosigma     1
# 94      t0_update_sla_fail               waratah     1

# %% [markdown]
# ### Non-alerting workflow counts

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    display(counts)
# Out:
#                   message_type              customer  head
# 201           t0_missing_files             tremblant    71
# 244          t0_received_files             tremblant    69
# 241          t0_received_files             slatepath    68
# 198           t0_missing_files             slatepath    65
# 296     t0_update_sla_recovery             tremblant    53
# 288     t0_update_sla_recovery             hudsonbay    52
# 246          t0_received_files               vivaldi    48
# 231          t0_received_files             hudsonbay    45
# 236          t0_received_files              lonepine    35
# 228          t0_received_files                 engle    33
# 79        daily_received_files              lonepine    31
# 273         t0_update_sla_fail             tremblant    31
# 178           t0_missing_files        beta-tremblant    27
# 262         t0_update_sla_fail             hudsonbay    27
# 229          t0_received_files                 helix    26
# 187           t0_missing_files                 helix    26
# 218          t0_received_files          avalonglobal    25
# 29         daily_missing_files              lonepine    24
# 76        daily_received_files                 helix    21
# 223          t0_received_files        beta-tremblant    19
# 21         daily_missing_files              fortress    19
# 203           t0_missing_files                zimmer    17
# 142  daily_update_sla_recovery             crestline    17
# 20         daily_missing_files             fairmount    17
# 291     t0_update_sla_recovery                 junto    17
# 69        daily_received_files             fairmount    16
# 189           t0_missing_files             hudsonbay    16
# 173           t0_missing_files          avalonglobal    16
# 170           t0_missing_files                   ako    15
# 216          t0_received_files                   ako    15
# 247          t0_received_files                zimmer    15
# 13         daily_missing_files             braidwell    14
# 64        daily_received_files             braidwell    14
# 67        daily_received_files            conversant    14
# 104      daily_update_sla_fail          cypressfunds    13
# 215          t0_received_files               adelphi    12
# 179           t0_missing_files         beta-valueact    12
# 63        daily_received_files         beta-valueact    12
# 169           t0_missing_files               adelphi    12
# 190           t0_missing_files                   ion    11
# 226          t0_received_files               contour    11
# 160  daily_update_sla_recovery               soroban    11
# 183           t0_missing_files               contour    11
# 11         daily_missing_files        beta-tremblant     9
# 260         t0_update_sla_fail               contour     9
# 10         daily_missing_files       beta-sachemhead     9
# 232          t0_received_files                   ion     9
# 89        daily_received_files              valueact     9
# 26         daily_missing_files              jennison     9
# 9          daily_missing_files            beta-junto     8
# 61        daily_received_files            beta-junto     8
# 93       daily_update_sla_fail             altimeter     8
# 221          t0_received_files            beta-junto     8
# 251         t0_update_sla_fail             altimeter     8
# 294     t0_update_sla_recovery             slatepath     8
# 230          t0_received_files             honeycomb     8
# 177           t0_missing_files            beta-junto     8
# 188           t0_missing_files             honeycomb     8
# 106      daily_update_sla_fail              fortress     7
# 31         daily_missing_files              magnetar     7
# 191           t0_missing_files               jericho     7
# 92       daily_update_sla_fail              altapark     7
# 233          t0_received_files               jericho     7
# 270         t0_update_sla_fail             slatepath     6
# 240          t0_received_files           rocksprings     6
# 222          t0_received_files         beta-lonepine     6
# 197           t0_missing_files           rocksprings     6
# 292     t0_update_sla_recovery              lonepine     6
# 18         daily_missing_files             crestline     6
# 184           t0_missing_files                corvex     6
# 75        daily_received_files                  gsam     6
# 77        daily_received_files              jennison     6
# 73        daily_received_files            goldentree     6
# 285     t0_update_sla_recovery               contour     6
# 25         daily_missing_files                  gsam     6
# 16         daily_missing_files               contour     6
# 128      daily_update_sla_fail           sunleyhouse     5
# 103      daily_update_sla_fail             crestline     5
# 24         daily_missing_files            goldentree     5
# 40         daily_missing_files                   sir     5
# 208             t0_non_current           maverickcap     5
# 195           t0_missing_files                 munro     5
# 17         daily_missing_files                corvex     5
# 168           t0_missing_files                 adage     5
# 199           t0_missing_files              sunriver     5
# 242          t0_received_files              sunriver     5
# 41         daily_missing_files               soroban     5
# 238          t0_received_files                 munro     5
# 39         daily_missing_files                scopia     5
# 266         t0_update_sla_fail                 junto     5
# 214          t0_received_files                 adage     5
# 182           t0_missing_files            castlehook     4
# 225          t0_received_files            castlehook     4
# 234          t0_received_files                 junto     4
# 5          daily_missing_files          avalonglobal     4
# 284     t0_update_sla_recovery             braidwell     4
# 59        daily_received_files              bayberry     4
# 62        daily_received_files        beta-tremblant     4
# 7          daily_missing_files              bayberry     4
# 127      daily_update_sla_fail                summit     4
# 143  daily_update_sla_recovery          cypressfunds     4
# 38         daily_missing_files            sachemhead     4
# 286     t0_update_sla_recovery            conversant     3
# 90        daily_received_files     washingtonharbour     3
# 4          daily_missing_files               artisan     3
# 105      daily_update_sla_fail                 eagle     3
# 277     t0_update_sla_recovery                 adage     3
# 137      daily_update_sla_fail                zimmer     3
# 132      daily_update_sla_fail             tremblant     3
# 153  daily_update_sla_recovery               lombard     3
# 126      daily_update_sla_fail               soroban     3
# 144  daily_update_sla_recovery                 eagle     3
# 121      daily_update_sla_fail                 minot     3
# 46         daily_missing_files     washingtonharbour     3
# 99       daily_update_sla_fail        beta-tremblant     3
# 202           t0_missing_files              valueact     3
# 32         daily_missing_files               maltese     3
# 57        daily_received_files               artisan     3
# 196           t0_missing_files                  rdst     3
# 245          t0_received_files              valueact     3
# 248         t0_update_sla_fail                 adage     3
# 272         t0_update_sla_fail                  toms     3
# 200           t0_missing_files             thorntree     2
# 0       broker_update_sla_fail                dorsal     2
# 36         daily_missing_files                  rdst     2
# 255         t0_update_sla_fail          avalonglobal     2
# 257         t0_update_sla_fail          beta-contour     2
# 19         daily_missing_files                dorsal     2
# 252         t0_update_sla_fail               anomaly     2
# 261         t0_update_sla_fail                 engle     2
# 243          t0_received_files             thorntree     2
# 58        daily_received_files          avalonglobal     2
# 55           daily_non_current                zimmer     2
# 204             t0_non_current           ardmoreroad     2
# 186           t0_missing_files                  gsam     2
# 162  daily_update_sla_recovery           sunleyhouse     2
# 163  daily_update_sla_recovery             tremblant     2
# 167  daily_update_sla_recovery     washingtonharbour     2
# 194           t0_missing_files            millstreet     2
# 116      daily_update_sla_fail               lombard     2
# 135      daily_update_sla_fail     washingtonharbour     2
# 115      daily_update_sla_fail              lingotto     2
# 96       daily_update_sla_fail  beta-1-ideaanalytics     2
# 295     t0_update_sla_recovery                  toms     2
# 15         daily_missing_files               catrock     2
# 161  daily_update_sla_recovery                summit     2
# 66        daily_received_files               catrock     2
# 86        daily_received_files               soroban     2
# 81        daily_received_files                 munro     2
# 68        daily_received_files             crestline     2
# 70        daily_received_files              fortress     2
# 44         daily_missing_files             tremblant     2
# 48           daily_non_current        beta-tremblant     2
# 51           daily_non_current               lombard     2
# 152  daily_update_sla_recovery              lingotto     2
# 282     t0_update_sla_recovery          avalonglobal     2
# 43         daily_missing_files           tigerglobal     2
# 279     t0_update_sla_recovery             altimeter     2
# 287     t0_update_sla_recovery                 engle     2
# 88        daily_received_files             tremblant     2
# 8          daily_missing_files          beta-contour     2
# 276         t0_update_sla_fail                zimmer     2
# 280     t0_update_sla_recovery               anomaly     2
# 94       daily_update_sla_fail              bayberry     1
# 95       daily_update_sla_fail       beta-1-aventail     1
# 97       daily_update_sla_fail          beta-contour     1
# 98       daily_update_sla_fail               beta-d1     1
# 2       broker_update_sla_fail                summit     1
# 283     t0_update_sla_recovery       beta-1-aventail     1
# 23         daily_missing_files             gamecreek     1
# 3          daily_missing_files                 arosa     1
# 140  daily_update_sla_recovery        beta-tremblant     1
# 141  daily_update_sla_recovery                corvex     1
# 146  daily_update_sla_recovery            goldentree     1
# 145  daily_update_sla_recovery              fortress     1
# 147  daily_update_sla_recovery                  gsam     1
# 45         daily_missing_files              valueact     1
# 72        daily_received_files             gamecreek     1
# 71        daily_received_files               frazier     1
# 74        daily_received_files              gppfunds     1
# 151  daily_update_sla_recovery                 junto     1
# 123      daily_update_sla_fail                  rdst     1
# 149  daily_update_sla_recovery       ias-maverickcap     1
# 50           daily_non_current             honeycomb     1
# 148  daily_update_sla_recovery                 helix     1
# 49           daily_non_current              cartenna     1
# 47         daily_missing_files                yiheng     1
# 124      daily_update_sla_fail                samlyn     1
# 125      daily_update_sla_fail                   see     1
# 154  daily_update_sla_recovery               maltese     1
# 150  daily_update_sla_recovery              ideamgmt     1
# 114      daily_update_sla_fail                 junto     1
# 117      daily_update_sla_fail              longpond     1
# 109      daily_update_sla_fail                  gsam     1
# 108      daily_update_sla_fail              gppfunds     1
# 134      daily_update_sla_fail              veristar     1
# 136      daily_update_sla_fail                 weiss     1
# 107      daily_update_sla_fail            goldentree     1
# 138  daily_update_sla_recovery             altimeter     1
# 130      daily_update_sla_fail              surgocap     1
# 131      daily_update_sla_fail                  toms     1
# 133      daily_update_sla_fail             twocreeks     1
# 129      daily_update_sla_fail              sunriver     1
# 91        daily_received_files                yiheng     1
# 122      daily_update_sla_fail                paloma     1
# 120      daily_update_sla_fail                   mig     1
# 118      daily_update_sla_fail               maltese     1
# 119      daily_update_sla_fail           maverickcap     1
# 112      daily_update_sla_fail              ideamgmt     1
# 111      daily_update_sla_fail       ias-maverickcap     1
# 110      daily_update_sla_fail                 helix     1
# 113      daily_update_sla_fail                   jne     1
# 1       broker_update_sla_fail              longpond     1
# 290     t0_update_sla_recovery         intrinsicedge     1
# 289     t0_update_sla_recovery              interval     1
# 278     t0_update_sla_recovery               adelphi     1
# 281     t0_update_sla_recovery              aregence     1
# 6          daily_missing_files              aventail     1
# 60        daily_received_files       beta-1-aventail     1
# 82        daily_received_files                paloma     1
# 83        daily_received_files                  rdst     1
# 84        daily_received_files            sachemhead     1
# 85        daily_received_files                   sir     1
# 87        daily_received_files              sunriver     1
# 22         daily_missing_files               frazier     1
# 65        daily_received_files            castlehook     1
# 78        daily_received_files                 junto     1
# 102      daily_update_sla_fail                corvex     1
# 80        daily_received_files              longpond     1
# 100      daily_update_sla_fail                camber     1
# 101      daily_update_sla_fail            castlehook     1
# 159  daily_update_sla_recovery                   see     1
# 155  daily_update_sla_recovery                   mig     1
# 185           t0_missing_files               frazier     1
# 157  daily_update_sla_recovery           rocksprings     1
# 205             t0_non_current                 atika     1
# 206             t0_non_current                camber     1
# 207             t0_non_current                 helix     1
# 209             t0_non_current              monashee     1
# 211             t0_non_current            sourcerock     1
# 210             t0_non_current                  rdst     1
# 53           daily_non_current                  rdst     1
# 52           daily_non_current              monashee     1
# 27         daily_missing_files                 junto     1
# 56        daily_received_files                 arosa     1
# 54           daily_non_current             twocreeks     1
# 35         daily_missing_files                paloma     1
# 33         daily_missing_files            millstreet     1
# 34         daily_missing_files                 munro     1
# 30         daily_missing_files              longpond     1
# 28         daily_missing_files             kathmandu     1
# 193           t0_missing_files              longpond     1
# 192           t0_missing_files               kinetic     1
# 217          t0_received_files                 atika     1
# 213             t0_non_current               waratah     1
# 212             t0_non_current                  toms     1
# 158  daily_update_sla_recovery                samlyn     1
# 164  daily_update_sla_recovery             twocreeks     1
# 165  daily_update_sla_recovery              veristar     1
# 139  daily_update_sla_recovery       beta-1-aventail     1
# 174           t0_missing_files                 avoro     1
# 176           t0_missing_files          beta-contour     1
# 180           t0_missing_files                 boone     1
# 181           t0_missing_files               bridger     1
# 175           t0_missing_files              beta-ako     1
# 172           t0_missing_files                 atika     1
# 171           t0_missing_files                 arosa     1
# 166  daily_update_sla_recovery           vestalpoint     1
# 156  daily_update_sla_recovery                paloma     1
# 275         t0_update_sla_fail               waratah     1
# 274         t0_update_sla_fail              twosigma     1
# 263         t0_update_sla_fail              interval     1
# 235          t0_received_files               kinetic     1
# 265         t0_update_sla_fail                   jne     1
# 264         t0_update_sla_fail         intrinsicedge     1
# 239          t0_received_files                  rdst     1
# 237          t0_received_files              longpond     1
# 224          t0_received_files               bridger     1
# 227          t0_received_files                corvex     1
# 249         t0_update_sla_fail               adelphi     1
# 250         t0_update_sla_fail              altapark     1
# 219          t0_received_files                 avoro     1
# 220          t0_received_files              beta-ako     1
# 269         t0_update_sla_fail                  rdst     1
# 271         t0_update_sla_fail              surgocap     1
# 253         t0_update_sla_fail              aregence     1
# 258         t0_update_sla_fail        beta-tremblant     1
# 259         t0_update_sla_fail             braidwell     1
# 267         t0_update_sla_fail              longpond     1
# 268         t0_update_sla_fail           maverickcap     1
# 37         daily_missing_files           rocksprings     1
# 42         daily_missing_files              sunriver     1
# 254         t0_update_sla_fail                 arosa     1
# 256         t0_update_sla_fail       beta-1-aventail     1
# 297     t0_update_sla_recovery               waratah     1
# 293     t0_update_sla_recovery                  rdst     1
# 14         daily_missing_files            castlehook     1
# 12         daily_missing_files                 boone     1
# 298     t0_update_sla_recovery                zimmer     1

# %% [markdown]
# ### Latest Daily Recovery Times

# %%
dailyRecoveryMessages = df[df['message_type'] == 'daily_update_sla_recovery'] 
latestTimes = dailyRecoveryMessages.groupby(['customer', 'message_type'])['datetime'].max().reset_index()
display(latestTimes)
# Out:
#              customer               message_type            datetime
# 0           altimeter  daily_update_sla_recovery 2025-04-04 09:44:57
# 1     beta-1-aventail  daily_update_sla_recovery 2025-01-07 11:46:48
# 2      beta-tremblant  daily_update_sla_recovery 2025-01-02 09:10:34
# 3              corvex  daily_update_sla_recovery 2025-02-12 11:22:49
# 4           crestline  daily_update_sla_recovery 2025-04-09 12:47:56
# 5        cypressfunds  daily_update_sla_recovery 2025-03-03 09:52:56
# 6               eagle  daily_update_sla_recovery 2025-03-11 09:02:48
# 7            fortress  daily_update_sla_recovery 2025-03-06 13:11:49
# 8          goldentree  daily_update_sla_recovery 2025-02-03 08:49:30
# 9                gsam  daily_update_sla_recovery 2025-01-01 10:14:01
# 10              helix  daily_update_sla_recovery 2025-01-26 09:45:40
# 11    ias-maverickcap  daily_update_sla_recovery 2025-01-17 09:02:03
# 12           ideamgmt  daily_update_sla_recovery 2025-03-04 15:15:32
# 13              junto  daily_update_sla_recovery 2025-03-08 08:42:30
# 14           lingotto  daily_update_sla_recovery 2025-04-01 19:06:03
# 15            lombard  daily_update_sla_recovery 2025-04-07 07:12:40
# 16            maltese  daily_update_sla_recovery 2025-01-23 10:54:42
# 17                mig  daily_update_sla_recovery 2025-02-19 08:50:52
# 18             paloma  daily_update_sla_recovery 2025-02-05 11:35:17
# 19        rocksprings  daily_update_sla_recovery 2025-01-29 08:02:31
# 20             samlyn  daily_update_sla_recovery 2025-02-03 09:00:57
# 21                see  daily_update_sla_recovery 2025-03-27 13:30:39
# 22            soroban  daily_update_sla_recovery 2025-03-29 15:18:03
# 23             summit  daily_update_sla_recovery 2025-02-13 10:20:44
# 24        sunleyhouse  daily_update_sla_recovery 2025-01-23 12:09:21
# 25          tremblant  daily_update_sla_recovery 2025-02-12 11:47:51
# 26          twocreeks  daily_update_sla_recovery 2025-03-05 09:56:48
# 27           veristar  daily_update_sla_recovery 2025-03-04 12:31:53
# 28        vestalpoint  daily_update_sla_recovery 2025-03-21 09:40:18
# 29  washingtonharbour  daily_update_sla_recovery 2025-04-02 12:03:48

# %% [markdown]
# ### Latest T0 Recovery Times

# %%
dailyRecoveryMessages = df[df['message_type'] == 't0_update_sla_recovery'] 
latestTimes = dailyRecoveryMessages.groupby(['customer', 'message_type'])['datetime'].max().reset_index()
display(latestTimes)
# Out:
#            customer            message_type            datetime
# 0             adage  t0_update_sla_recovery 2025-01-06 23:38:09
# 1           adelphi  t0_update_sla_recovery 2025-04-01 20:00:25
# 2         altimeter  t0_update_sla_recovery 2025-04-04 10:04:20
# 3           anomaly  t0_update_sla_recovery 2025-02-14 19:06:51
# 4          aregence  t0_update_sla_recovery 2025-01-27 21:04:29
# 5      avalonglobal  t0_update_sla_recovery 2025-03-24 00:00:33
# 6   beta-1-aventail  t0_update_sla_recovery 2025-01-02 20:25:31
# 7         braidwell  t0_update_sla_recovery 2025-04-07 18:32:41
# 8           contour  t0_update_sla_recovery 2025-03-14 21:04:07
# 9        conversant  t0_update_sla_recovery 2025-01-13 17:30:31
# 10            engle  t0_update_sla_recovery 2025-03-12 21:25:43
# 11        hudsonbay  t0_update_sla_recovery 2025-04-10 01:01:48
# 12         interval  t0_update_sla_recovery 2025-01-22 19:06:20
# 13    intrinsicedge  t0_update_sla_recovery 2025-01-15 19:46:47
# 14            junto  t0_update_sla_recovery 2025-04-09 19:46:29
# 15         lonepine  t0_update_sla_recovery 2025-01-14 00:10:19
# 16             rdst  t0_update_sla_recovery 2025-03-05 20:00:36
# 17        slatepath  t0_update_sla_recovery 2025-04-08 19:27:28
# 18             toms  t0_update_sla_recovery 2025-03-03 20:16:56
# 19        tremblant  t0_update_sla_recovery 2025-04-07 21:47:30
# 20          waratah  t0_update_sla_recovery 2025-01-03 01:04:40
# 21           zimmer  t0_update_sla_recovery 2025-01-21 19:30:11

# %%
# Filter for missing files notifications
missing_files_df = df[df['message_type'].isin(['t0_missing_files', 'daily_missing_files'])].copy()

# Create notification type column from message_type using .loc
missing_files_df.loc[:, 'notification_type'] = missing_files_df['message_type'].apply(
    lambda x: 'T0' if 't0_' in x else 'Daily')

# Determine who gets notified (this is based on isAtChannel) using .loc
missing_files_df.loc[:, 'recipient'] = missing_files_df['isAtChannel'].apply(
    lambda x: 'All channel members' if x else 'Channel subscribers')

# Select and reorder columns as requested
result_df = missing_files_df[['customer', 'notification_type', 'recipient', 'datetime', 'head']]

# Sort by datetime for better organization
result_df = result_df.sort_values(['customer', 'notification_type', 'datetime'])

# Preview the result
print(f"Total missing files notifications: {len(result_df)}")
result_df.head(10)
# Out:
# Total missing files notifications: 583
#      customer notification_type            recipient            datetime  \
# 121     adage                T0  Channel subscribers 2025-01-02 22:15:15
# 174     adage                T0  Channel subscribers 2025-01-03 22:15:15
# 234     adage                T0  Channel subscribers 2025-01-06 22:15:15
# 289     adage                T0  Channel subscribers 2025-01-07 22:15:15
# 326     adage                T0  Channel subscribers 2025-01-08 22:15:15
# 1779  adelphi                T0  Channel subscribers 2025-03-10 19:00:03
# 1810  adelphi                T0  Channel subscribers 2025-03-11 19:00:03
# 1850  adelphi                T0  Channel subscribers 2025-03-12 19:00:05
# 1882  adelphi                T0  Channel subscribers 2025-03-13 19:00:03
# 1918  adelphi                T0  Channel subscribers 2025-03-14 19:00:01
#
#                               head
# 121     T0 files missing for Adage
# 174     T0 files missing for Adage
# 234     T0 files missing for Adage
# 289     T0 files missing for Adage
# 326     T0 files missing for Adage
# 1779  T0 files missing for adelphi
# 1810  T0 files missing for adelphi
# 1850  T0 files missing for adelphi
# 1882  T0 files missing for adelphi
# 1918  T0 files missing for adelphi

# %%
# Export to CSV
result_df.to_csv('missing_files_notifications.csv', index=False)
print("CSV file 'missing_files_notifications.csv' created successfully!")
# Out:
# CSV file 'missing_files_notifications.csv' created successfully!
